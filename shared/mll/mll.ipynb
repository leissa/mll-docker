// %% [markdown]
// # MLL Notebook
//
// Jupyter Notebook is a software which allows to execute pieces of code interactively in the browser. This file gives an overview of its capabilities tailored towards the setting of this workshop. It closely follows the examples in Main.java.

// %%
// you can add other imports here as needed
import mll.*;

// %%
// 1) Test plotting a function
var x = Util.getx(-10,  10, 100);
var y = Util.gety(x, x_ -> 1 / (1 + Math.exp(-x_)));
Util.viewPlot(x, y, "example");
// Out:
// BufferedImage@75fd7ef9: type = 1 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=0 IntegerInterleavedRaster: width = 600 height = 400 #Bands = 3 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
// 2) Test plotting a graph via dot
String dot = """
    digraph g {
        a -> b
        c -> b
        b -> d
    }
""";
Util.viewDot(dot);
// Out:
// BufferedImage@688ae52d: type = 2 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=ff000000 IntegerInterleavedRaster: width = 134 height = 188 #Bands = 4 xOff = 0 yOff = 0 dataOffset[0] 0

// %%
// 3) Test compilation via LLVM
Util.runLLVM("helloworld");
// Out:
// Hello from LLVM!

// %%
// 4) Test code optimization with LLVM
Util.saveLLVMOpt("helloworld", 3);
Util.runLLVM("helloworld-O3");
// Out:
// Optimized LLVM code: out/llvm/helloworld-O3.ll
// Hello from LLVM!
